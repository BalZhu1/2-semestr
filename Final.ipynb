# %% [markdown]
# <a href="https://colab.research.google.com/github/BalZhu1/2-semestr/blob/main/Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Medal
import pandas as pd
df = pd.read_html('https://ru.m.wikipedia.org/wiki/%D0%9C%D0%B5%D0%B4%D0%B0%D0%BB%D1%8C%D0%BD%D1%8B%D0%B9_%D0%B7%D0%B0%D1%87%D1%91%D1%82_%D0%BD%D0%B0_%D0%BB%D0%B5%D1%82%D0%BD%D0%B8%D1%85_%D0%9E%D0%BB%D0%B8%D0%BC%D0%BF%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D1%85_%D0%B8%D0%B3%D1%80%D0%B0%D1%85_2016') 
len(df)

# %%
d = df[0]
d

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
path = r"/content/drive/My Drive/Final123/"

# %%
d.to_csv(path+'Medals.csv',index = True)

# %%
#Calendar
import pandas as pd
df = pd.read_html('https://www.sport-express.ru/olympics/rio2016/calendar/')
len(df)
# Out:
# 1

# %%
d = df[0]
d
# Out:
#                          август  ... Unnamed: 20_level_0
#                          август  ... Unnamed: 20_level_1
#                  День олимпиады  ... Unnamed: 20_level_2
# 0          Академическая гребля  ...                  14
# 1                     Бадминтон  ...                   5
# 2                     Баскетбол  ...                   2
# 3                         Батут  ...                   2
# 4                     Бич-волей  ...                   2
# 5                          Бокс  ...                  13
# 6                      Вело-bmx  ...                   2
# 7                      Велотрек  ...                  10
# 8                     Велошоссе  ...                   4
# 9                   Водное поло  ...                   2
# 10                     Волейбол  ...                   2
# 11               Вольная борьба  ...                  12
# 12                      Гандбол  ...                   2
# ...

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
path = r"/content/drive/My Drive/Final123/"

# %%
d.to_csv(path+'Calendar.csv',index = False)

# %%
#Athletes
import pandas as pd
df = pd.read_html('https://www.championat.com/olympic/_olympismog/tournament/386/players/')
len(df)
# Out:
# 1

# %%
d = df[0]
d
# Out:
#                Спортсмен  Unnamed: 1      Команда          ДР   Рост   Вес
# 0              Пак Сон А         NaN  Южная Корея  16.04.1991  168.0  61.0
# 1           Андрея Ааней         NaN      Румыния  18.11.1993    NaN   NaN
# 2            Нестор Абад         NaN      Испания         NaN    NaN   NaN
# 3      Патимат Абакарова         NaN  Азербайджан  23.10.1994  165.0  49.0
# 4              Люк Абало         NaN      Франция  06.09.1984  182.0   NaN
# ...                  ...         ...          ...         ...    ...   ...
# 6453   Дьюрдьина Яукович         NaN   Черногория  24.02.1997  185.0   NaN
# 6454  Мухаммед Анас Яхия         NaN        Индия  17.09.1994    NaN   NaN
# 6455     Матеуш Яхлевски         NaN       Польша  27.12.1984  184.0   NaN
# 6456    Анастасия Яцевич         NaN     Беларусь  18.01.1985  158.0  46.0
# 6457             Сы Яцзе         NaN        Китай  04.12.1998    NaN   NaN
#
# [6458 rows x 6 columns]

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
path = r"/content/drive/My Drive/Final123/"

# %%
d.to_csv(path+'Athletes.csv',index = False)

# %%
#Kazakhstan
import pandas as pd
df = pd.read_html('https://ru.wikipedia.org/wiki/%D0%9A%D0%B0%D0%B7%D0%B0%D1%85%D1%81%D1%82%D0%B0%D0%BD_%D0%BD%D0%B0_%D0%BB%D0%B5%D1%82%D0%BD%D0%B8%D1%85_%D0%9E%D0%BB%D0%B8%D0%BC%D0%BF%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D1%85_%D0%B8%D0%B3%D1%80%D0%B0%D1%85_2016#%D0%9C%D0%B5%D0%B4%D0%B0%D0%BB%D0%B8')
len(df)
# Out:
# 43

# %%
d = df[0]
d
# Out:
#                        Казахстан на Олимпийских играх  ... Unnamed: 3
# 0                                                 NaN  ...        NaN
# 1                                             Код МОК  ...        NaN
# 2                                                 НОК  ...        NaN
# 3                   Олимпийские игры в Рио-де-Жанейро  ...        NaN
# 4                                          Спортсмены  ...        NaN
# 5                                          Знаменосец  ...        NaN
# 6                                      МедалиМесто 22  ...        NaN
# 7                                             Золото3  ...    Всего18
# 8                  Участие в летних Олимпийских играх  ...        NaN
# 9      1996 • 2000 • 2004 • 2008 • 2012 • 2016 • 2020  ...        NaN
# 10                 Участие в зимних Олимпийских играх  ...        NaN
# 11     1994 • 1998 • 2002 • 2006 • 2010 • 2014 • 2018  ...        NaN
# ...

# %%
d.to_csv(path+'Kazakhstan.csv',index = False)

# %%
#Tokio
import pandas as pd
df = pd.read_html('https://en.wikipedia.org/wiki/2020_Summer_Olympics')
len(df)
# Out:
# 24

# %%
d = df[0]
d
# Out:
#                                     0                                  1
# 0                                 NaN                                NaN
# 1                           Host city                       Tokyo, Japan
# 2                               Motto               United by Emotion[a]
# 3                             Nations                     205 (expected)
# 4                            Athletes                  11,091 (expected)
# 5                              Events  339 in 33 sports (50 disciplines)
# 6                             Opening                       23 July 2021
# 7                             Closing                      8 August 2021
# 8                           Opened by        Emperor Naruhito (expected)
# 9                             Stadium             Japan National Stadium
# 10                             Summer                             Summer
# 11            ← Rio 2016 Paris 2024 →            ← Rio 2016 Paris 2024 →
# ...

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
path = r"/content/drive/My Drive/Final123/"

# %%
d.to_csv(path+'TOKYO2020.csv',index = False)
